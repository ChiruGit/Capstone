# %%
import requests

# %%
import json

# %%
import pandas as pd

# %%
token= "AIzaSyA6nUOqZFkxGrnpxn3WxYJhesUHhtPLCoA"

# %%
def req_googleKG(req1,req2):
   # r = requests.get("https://graph.facebook.com/v3.0/"+req,{'access_token': token})
   # r="https://kgsearch.googleapis.com/v1/entities:search?languages=en&limit=10&query="+req1+"&types="+req2+"&key="+token
    r = requests.get("https://kgsearch.googleapis.com/v1/entities:search?languages=en&limit=20&query="+req1+"&types="+req2+"&key="+token)
    return r

# %%
req1=["Kamala+Harris","Loretta+Sanchez","Duf+Sundheim","Phil+Wyman","Tom+Del+Beccaro","Greg+Conlon","Steve+Stokes","George+C.Yang","Karen+Roseberry","Gail+K.Lightfoot","Massie+Munroe","Pamela+Elizondo","Tom+Palzer","Ron+Unz","Don+Krampe","Eleanor+García","Jarrell+Williamson","Von+Hougo","President+Cristina+Grappo","Jerry+J.Laws","Mark+Matthew+Herd","John+Thompson+Parker","Ling+Ling+Shi","Herbert+G.Peters","Emory+Peretz+Rodgers","Mike+Beitiks","Clive+Grey","Jason+Hanania","Paul+Merritt","Jason+Kraus","Don+J.Grundmann","Scott+A.Vineberg","Tim+Gildersleeve","Gar+Myers","Billy+Falling","Ric+M.Llewellyn","Alexis+Stuart"]
#req1="Kamala+Harris"
req2="Organization"
req3="Event"

# %%
rorg = []
revent = []

# %%
print(req1[0])
# Out:
# Kamala+Harris

# %%
senatororg = []
senatorevent = []

# %%
for i in range(1,37):
    rorg=req_googleKG(req1[i],req2)
    revent=req_googleKG(req1[i],req3)
    
    json_orgdata = rorg.json()
    json_eventdata = revent.json()


    resultsorg=json_orgdata['itemListElement']
    resultsevent=json_eventdata['itemListElement']


    #print(req1[i]);
    for j in range(0,3):
        print(req1[i]);
        try:
              senatororg.append([req1[i],resultsorg[j]['result']['name'],resultsorg[j]['result']['detailedDescription']['articleBody']])
        except IndexError:
              print("skipped")
    for k in range(0,3):
        print(req1[i]);
        try:
              senatorevent.append([req1[i],resultsevent[k]['result']['name'],resultsevent[k]['result']['detailedDescription']['articleBody']])
        except IndexError:
              print("skipped")
# Out:
# Loretta+Sanchez
# Loretta+Sanchez
# Loretta+Sanchez
# Loretta+Sanchez
# Loretta+Sanchez
# Loretta+Sanchez
# Duf+Sundheim
# skipped
# Duf+Sundheim
# skipped
# Duf+Sundheim
# skipped
# Duf+Sundheim
# skipped
# Duf+Sundheim
# skipped
# Duf+Sundheim
# skipped
# Phil+Wyman
# skipped
# Phil+Wyman
# skipped
# Phil+Wyman
# skipped
# Phil+Wyman
# Phil+Wyman
# Phil+Wyman
# Tom+Del+Beccaro
# skipped
# Tom+Del+Beccaro
# skipped
# Tom+Del+Beccaro
# skipped
# Tom+Del+Beccaro
# Tom+Del+Beccaro
# Tom+Del+Beccaro
# Greg+Conlon
# skipped
# Greg+Conlon
# skipped
# Greg+Conlon
# skipped
# Greg+Conlon
# Greg+Conlon
# skipped
# Greg+Conlon
# skipped
# Steve+Stokes
# skipped
# Steve+Stokes
# skipped
# Steve+Stokes
# skipped
# Steve+Stokes
# Steve+Stokes
# Steve+Stokes
# George+C.Yang
# skipped
# George+C.Yang
# skipped
# George+C.Yang
# skipped
# George+C.Yang
# skipped
# George+C.Yang
# skipped
# George+C.Yang
# skipped
# Karen+Roseberry
# skipped
# Karen+Roseberry
# skipped
# Karen+Roseberry
# skipped
# Karen+Roseberry
# skipped
# Karen+Roseberry
# skipped
# Karen+Roseberry
# skipped
# Gail+K.Lightfoot
# skipped
# Gail+K.Lightfoot
# skipped
# Gail+K.Lightfoot
# skipped
# Gail+K.Lightfoot
# skipped
# Gail+K.Lightfoot
# skipped
# Gail+K.Lightfoot
# skipped
# Massie+Munroe
# skipped
# Massie+Munroe
# skipped
# Massie+Munroe
# skipped
# Massie+Munroe
# skipped
# Massie+Munroe
# skipped
# Massie+Munroe
# skipped
# Pamela+Elizondo
# skipped
# Pamela+Elizondo
# skipped
# Pamela+Elizondo
# skipped
# Pamela+Elizondo
# Pamela+Elizondo
# skipped
# Pamela+Elizondo
# skipped
# Tom+Palzer
# skipped
# Tom+Palzer
# skipped
# Tom+Palzer
# skipped
# Tom+Palzer
# skipped
# Tom+Palzer
# skipped
# Tom+Palzer
# skipped
# Ron+Unz
# Ron+Unz
# Ron+Unz
# Ron+Unz
# Ron+Unz
# Ron+Unz
# Don+Krampe
# skipped
# Don+Krampe
# skipped
# Don+Krampe
# skipped
# Don+Krampe
# skipped
# Don+Krampe
# skipped
# Don+Krampe
# skipped
# Eleanor+García
# skipped
# Eleanor+García
# skipped
# Eleanor+García
# skipped
# Eleanor+García
# Eleanor+García
# Eleanor+García
# Jarrell+Williamson
# skipped
# Jarrell+Williamson
# skipped
# Jarrell+Williamson
# skipped
# Jarrell+Williamson
# Jarrell+Williamson
# Jarrell+Williamson
# skipped
# Von+Hougo
# skipped
# Von+Hougo
# skipped
# Von+Hougo
# skipped
# Von+Hougo
# skipped
# Von+Hougo
# skipped
# Von+Hougo
# skipped
# President+Cristina+Grappo
# skipped
# President+Cristina+Grappo
# skipped
# President+Cristina+Grappo
# skipped
# President+Cristina+Grappo
# skipped
# President+Cristina+Grappo
# skipped
# President+Cristina+Grappo
# skipped
# Jerry+J.Laws
# skipped
# Jerry+J.Laws
# skipped
# Jerry+J.Laws
# skipped
# Jerry+J.Laws
# skipped
# Jerry+J.Laws
# skipped
# Jerry+J.Laws
# skipped
# Mark+Matthew+Herd
# skipped
# Mark+Matthew+Herd
# skipped
# Mark+Matthew+Herd
# skipped
# Mark+Matthew+Herd
# Mark+Matthew+Herd
# Mark+Matthew+Herd
# John+Thompson+Parker
# skipped
# John+Thompson+Parker
# skipped
# John+Thompson+Parker
# skipped
# John+Thompson+Parker
# skipped
# John+Thompson+Parker
# skipped
# John+Thompson+Parker
# skipped
# Ling+Ling+Shi
# Ling+Ling+Shi
# skipped
# Ling+Ling+Shi
# skipped
# Ling+Ling+Shi
# Ling+Ling+Shi
# Ling+Ling+Shi
# skipped
# Herbert+G.Peters
# skipped
# Herbert+G.Peters
# skipped
# Herbert+G.Peters
# skipped
# Herbert+G.Peters
# skipped
# Herbert+G.Peters
# skipped
# Herbert+G.Peters
# skipped
# Emory+Peretz+Rodgers
# skipped
# Emory+Peretz+Rodgers
# skipped
# Emory+Peretz+Rodgers
# skipped
# Emory+Peretz+Rodgers
# skipped
# Emory+Peretz+Rodgers
# skipped
# Emory+Peretz+Rodgers
# skipped
# Mike+Beitiks
# skipped
# Mike+Beitiks
# skipped
# Mike+Beitiks
# skipped
# Mike+Beitiks
# skipped
# Mike+Beitiks
# skipped
# Mike+Beitiks
# skipped
# Clive+Grey
# skipped
# Clive+Grey
# skipped
# Clive+Grey
# skipped
# Clive+Grey
# skipped
# Clive+Grey
# skipped
# Clive+Grey
# skipped
# Jason+Hanania
# skipped
# Jason+Hanania
# skipped
# Jason+Hanania
# skipped
# Jason+Hanania
# skipped
# Jason+Hanania
# skipped
# Jason+Hanania
# skipped
# Paul+Merritt
# skipped
# Paul+Merritt
# skipped
# Paul+Merritt
# skipped
# Paul+Merritt
# Paul+Merritt
# skipped
# Paul+Merritt
# skipped
# Jason+Kraus
# skipped
# Jason+Kraus
# skipped
# Jason+Kraus
# skipped
# Jason+Kraus
# skipped
# Jason+Kraus
# skipped
# Jason+Kraus
# skipped
# Don+J.Grundmann
# skipped
# Don+J.Grundmann
# skipped
# Don+J.Grundmann
# skipped
# Don+J.Grundmann
# skipped
# Don+J.Grundmann
# skipped
# Don+J.Grundmann
# skipped
# Scott+A.Vineberg
# skipped
# Scott+A.Vineberg
# skipped
# Scott+A.Vineberg
# skipped
# Scott+A.Vineberg
# skipped
# Scott+A.Vineberg
# skipped
# Scott+A.Vineberg
# skipped
# Tim+Gildersleeve
# skipped
# Tim+Gildersleeve
# skipped
# Tim+Gildersleeve
# skipped
# Tim+Gildersleeve
# skipped
# Tim+Gildersleeve
# skipped
# Tim+Gildersleeve
# skipped
# Gar+Myers
# skipped
# Gar+Myers
# skipped
# Gar+Myers
# skipped
# Gar+Myers
# skipped
# Gar+Myers
# skipped
# Gar+Myers
# skipped
# Billy+Falling
# skipped
# Billy+Falling
# skipped
# Billy+Falling
# skipped
# Billy+Falling
# skipped
# Billy+Falling
# skipped
# Billy+Falling
# skipped
# Ric+M.Llewellyn
# skipped
# Ric+M.Llewellyn
# skipped
# Ric+M.Llewellyn
# skipped
# Ric+M.Llewellyn
# skipped
# Ric+M.Llewellyn
# skipped
# Ric+M.Llewellyn
# skipped
# Alexis+Stuart
# skipped
# Alexis+Stuart
# skipped
# Alexis+Stuart
# skipped
# Alexis+Stuart
# Alexis+Stuart
# Alexis+Stuart
# skipped

# %%
for i in range(0,len(senatororg)):
    print("*",i, "*", senatororg[i])
# Out:
# * 0 * ['Kamala+Harris', 'St. Francis Medical Center', 'St. Francis Medical Center is a not-for-profit hospital in Lynwood, California, US.']
# * 1 * ['Kamala+Harris', 'Westmount High School', 'Westmount High School is a public secondary school located at 4350 St. Catherine St. West in Westmount, Quebec, Canada. Westmount High is Quebec’s first and only public school to offer Advanced Placement courses.\n']
# * 2 * ['Kamala+Harris', 'Prime Healthcare Services', 'Prime Healthcare Services is an American private company. It was established in 2001 by Chairman of the Board Prem Reddy. It operates 45 acute care hospitals serving communities in San Bernardino, San Diego, Los Angeles, Inglewood, Orange County and Shasta County in California, Alabama, Florida, Georgia, Indiana, Michigan, Missouri, Nevada, New Jersey, Ohio, Pennsylvania, Kansas, Rhode Island and Texas. ']
# * 3 * ['Loretta+Sanchez', 'Katella High School', 'Katella High School is a public high school in Anaheim, California and is part of the Anaheim Union High School District. It serves 2,700 students in grades nine through twelve. The school’s mascot is the Knights.']
ine through twelve. The school’s mascot is the Knights.'], ['Loretta+Sanchez', 'Global Strategy Group', 'Global Strategy Group is an American public relations and research firm; specializing in research, strategic communications, digital strategy, grassroots and grasstops organizing, marketing and branding. '], ['Loretta+Sanchez', 'Chapman University', 'Chapman University is a private non-profit university located in Orange, California, United States. Chapman University encompasses ten schools and colleges: Dodge College of Film and Media Arts, Wilkinson College of Humanities and Social Sciences, Argyros School of Business and Economics, the School of Communication, Schmid College of Science and Technology, College of Performing Arts, Dale E. '], ['Ron+Unz', 'Walter Reed Middle School', 'Walter Reed Middle School is located in the Studio City neighborhood of Los Angeles, California, USA. Originally called North Hollywood Junior High School, the school was later renamed in honor of U.S. Army Major Walter Reed.\n'], ['Ron+Unz', "Moody's Analytics", "Moody's Analytics is a subsidiary of Moody's Corporation established in 2007 to focus on non-rating activities, separate from Moody's Investors Service. "], ['Ron+Unz', 'North Hollywood High School', 'North Hollywood High School is a public high school in North Hollywood in Los Angeles, California. NHHS is located in the San Fernando Valley and enrolls approximately 3,000 students each year. '], ['Ling+Ling+Shi', "Citizens' Climate Lobby", "Citizens' Climate Lobby is an international grassroots environmental group that trains and supports volunteers to build relationships with their elected representatives in order to influence climate policy. "]]

# %%
json_eventdata
# Out:
# {'@context': {'@vocab': 'http://schema.org/',
#   'EntitySearchResult': 'goog:EntitySearchResult',
#   'detailedDescription': 'goog:detailedDescription',
#   'goog': 'http://schema.googleapis.com/',
#   'kg': 'http://g.co/kg',
#   'resultScore': 'goog:resultScore'},
#  '@type': 'ItemList',
#  'itemListElement': [{'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/m/0g9wkxh',
#     '@type': ['Thing', 'Event'],
#     'detailedDescription': {'articleBody': 'The Jacobite rising of 1715, was the attempt by James Francis Edward Stuart to regain the thrones of England, Ireland and Scotland for the exiled House of Stuart.',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Jacobite_rising_of_1715'},
#     'image': {'contentUrl': 'http://t1.gstatic.com/images?q=tbn:ANd9GcRpActqlz6VXttIXKn0EaMFH1yIOyhgX9ZRNTm2_ZkKdI4G_4wh',
#      'url': 'https://en.wikipedia.org/wiki/Jacobite_rising_of_1715'},
#     'name': 'Jacobite rising of 1715'},
#    'resultScore': 1.876479},
#   {'@type': 'EntitySearchResult',
#    'result': {'@id': 'kg:/g/11hd5fbgqg',
#     '@type': ['Thing', 'Event'],
#     'description': 'Competition',
#     'detailedDescription': {'articleBody': 'The 1997 AAA Championships was an outdoor track and field competition organised by the Amateur Athletic Association, held from 24–25 July at Alexander Stadium in Birmingham, England. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/1997_AAA_Championships'},
#     'image': {'contentUrl': 'http://t3.gstatic.com/images?q=tbn:ANd9GcTnDoBuH9Z0fPQ9p5SyFrvW2IQozqksYUxsCWVVMV5ucU5Z8GVJ',
#      'url': 'https://en.wikipedia.org/wiki/1997_AAA_Championships'},
#     'name': '1997 AAA Championships'},
#    'resultScore': 1.092048}]}

# %%
resultsevent[0]['result']['detailedDescription']['articleBody']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-57-5f43d064d975> in <module>()
# ----> 1 resultsevent[0]['result']['detailedDescription']['articleBody']
#
# KeyError: 'detailedDescription'
