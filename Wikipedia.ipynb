# %% [markdown]
# ## Important links:
# Below link is git of a Berkely grad working on ethnography(study how people produce knowledge). Good deal of work on wikipedia.
# https://github.com/staeiou
# http://www.thehackerwithin.org/berkeley/posts/2016-02-17-wikiscraping-spring-2016.html
# The below repo has info wikipedia scrapping
# https://github.com/thehackerwithin/berkeley/tree/master/code_examples/scraping_wikipedia
#
# https://github.com/martin-majlis/Wikipedia-API
#
# #### Other sources below
# #https://pypi.org/project/wikipedia/
# #https://www.mediawiki.org/wiki/Manual:Pywikibot/Installation
#
# #### Tutorial for wikidata API
# #https://www.wikidata.org/wiki/Wikidata:Pywikibot_-_Python_3_Tutorial/Setting_up_Shop
# #https://www.wikidata.org/wiki/Wikidata:Pywikibot_-_Python_3_Tutorial/Data_Harvest

# %%
import wikipediaapi

# %%
import pywikibot

# %%
import json

# %%
#Testing wikibot
site = pywikibot.Site("en", "wikipedia")
#page = pywikibot.Page(site, "Douglas Adams")
page = pywikibot.Page(site, "Mark Matthew Herd")
item = pywikibot.ItemPage.fromPage(page)

#Print item page object
print(item)
# Out:
# [[wikidata:Q26899192]]

# %%
print(page.exists())
# Out:
# True

# %%
req = ["Ron Unz"]

page.append(pywikibot.Page(site, req[i]))
item.append(pywikibot.ItemPage.fromPage(page[i]))

# %%
from time import sleep

req = ["Loretta Sanchez","Ron Unz","Kamala Harris","Duf Sundheim","Phil Wyman","Tom Del Beccaro","Greg Conlon","Steve Stokes","George C.Yang","Karen Roseberry","Gail K.Lightfoot","Massie Munroe","Pamela Elizondo","Tom Palzer","Don Krampe","Eleanor García","Jarrell Williamson","Von Hougo","President Cristina Grappo","Jerry J.Laws","Mark Matthew Herd","John Thompson Parker","Ling Ling Shi","Herbert G.Peters","Emory Peretz Rodgers","Mike Beitiks","Clive Grey","Jason Hanania","Paul Merritt","Jason Kraus","Don J.Grundmann","Scott A.Vineberg","Tim Gildersleeve","Gar Myers","Billy Falling","Ric M.Llewellyn","Alexis Stuart"]
#req = ["Loretta Sanchez","Ron Unz","Kamala Harris"]
page = []
item = []

for i in range(0,len(req)):
    sleep(0.1)
    print(req[i])
    #try:
    page.append(pywikibot.Page(site, req[i]))
    if(page[i].exists()):
        item.append(pywikibot.ItemPage.fromPage(page[i]))
        #print(req[i], item[i])
    else:
        print("Page not found", i)
        
   # except IndexError:
       # print("skipped")
# Out:
# Loretta Sanchez
# Ron Unz
# Kamala Harris
# Duf Sundheim
# Phil Wyman
# Tom Del Beccaro
# Greg Conlon
# Page not found 6
# Steve Stokes
# Page not found 7
# George C.Yang
# Page not found 8
# Karen Roseberry
# Page not found 9
# Gail K.Lightfoot
# Page not found 10
# Massie Munroe
# Page not found 11
# Pamela Elizondo
# Page not found 12
# Tom Palzer
# Page not found 13
# Don Krampe
# Page not found 14
# Eleanor García
# Page not found 15
# Jarrell Williamson
# Page not found 16
# Von Hougo
# Page not found 17
# President Cristina Grappo
# Page not found 18
# Jerry J.Laws
# Page not found 19
# Mark Matthew Herd
# John Thompson Parker
# Page not found 21
# Ling Ling Shi
# Page not found 22
# Herbert G.Peters
# Page not found 23
# Emory Peretz Rodgers
# Page not found 24
# Mike Beitiks
# Page not found 25
# Clive Grey
# Page not found 26
# Jason Hanania
# Page not found 27
# Paul Merritt
# Page not found 28
# Jason Kraus
# Page not found 29
# Don J.Grundmann
# Page not found 30
# ...

# %%
#print(page)
print(len(item))
# Out:
# 7

# %%
#item[13]
item
# Out:
# [ItemPage('Q469094'),
#  ItemPage('Q7364500'),
#  ItemPage('Q10853588'),
#  ItemPage('Q5544956'),
#  ItemPage('Q7182574'),
#  ItemPage('Q7815556'),
#  ItemPage('Q26899192')]

# %%
#Education
item_dict = []
clm_dict = []

for i in range(0,len(item)):  
    item_dict.append(item[i].get())
    clm_dict.append(item_dict[i]["claims"])
 

print(len(item_dict))
#print(clm_dict[0])
# Out:
# 7

# %%
print(len(clm_dict))
# Out:
# 7

# %%
#print(item_dict)
print(clm_dict)
# Out:
# [{'P21': [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P21', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 6581072}, 'type': 'wikibase-entityid'}}, 'type': 'statement', 'id': 'q469094$0663E978-E8E2-432C-A9BF-4903C252EBFB', 'rank': 'normal', 'references': [{'snaks': {'P143': [{'snaktype': 'value', 'property': 'P143', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 11920}, 'type': 'wikibase-entityid'}}]}, 'snaks-order': ['P143'], 'hash': 'd5847b9b6032aa8b13dae3c2dfd9ed5d114d21b3'}]})], 'P373': [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P373', 'datatype': 'string', 'datavalue': {'value': 'Loretta Sanchez', 'type': 'string'}}, 'type': 'statement', 'id': 'q469094$2BC1C71B-C6FB-42B5-872E-1041E9FEBEEC', 'rank': 'normal', 'references': [{'snaks': {'P143': [{'snaktype': 'value', 'property': 'P143', 'dat
# ...

# %%
clm_list = []
for i in range(0,len(item)):
    clm_list.append(clm_dict[i]["P69"])
    
print(len(clm_list))
# Out:
# 7

# %%
#clm_list[1].toJSON()
#for clm in clm_list:
    #print(clm)
#print(dir(clm_list))
#print((clm_list))
#clm_list.shape

from numpy import array
a = array(clm_list)
print(a.shape)
# Out:
# (7,)

# %%
clm_list[1]
# Out:
# [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P69', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 13371}, 'type': 'wikibase-entityid'}}, 'type': 'statement', 'id': 'Q7364500$CF02D9EF-11BE-4FC7-8BAD-2AED220142C0', 'rank': 'normal', 'references': [{'snaks': {'P143': [{'snaktype': 'value', 'property': 'P143', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 328}, 'type': 'wikibase-entityid'}}]}, 'snaks-order': ['P143'], 'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1'}]}),
#  Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P69', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 41506}, 'type': 'wikibase-entityid'}}, 'type': 'statement', 'id': 'Q7364500$724EF85D-801F-42F3-8FB6-B36EAC15D8C0', 'rank': 'normal'})]

# %%
#print(clm_list[0])
#clm_trgt
clm_list_values = []
for i in range(0,len(item)):
    clm_list_values.append([])
    for clm in clm_list[i]:
        ...        
        clm_trgt = clm.getTarget()
        clm_list_values[i].append(clm_trgt)
        print(i)
        print(clm_trgt)
        
        #print(type(clm_trgt))
        #print(dir(clm_trgt))
# Out:
# 0
# [[wikidata:Q1805085]]
# 0
# [[wikidata:Q9842]]
# 0
# [[wikidata:Q168000]]
# 1
# [[wikidata:Q13371]]
# 1
# [[wikidata:Q41506]]
# 2
# [[wikidata:Q1068752]]
# 2
# [[wikidata:Q3577853]]
# 3
# [[wikidata:Q41506]]
# 3
# [[wikidata:Q7060409]]
# 4
# [[wikidata:Q129421]]
# 5
# [[wikidata:Q168756]]
# 5
# [[wikidata:Q992830]]
# 6
# [[wikidata:Q7894738]]
# 6
# [[wikidata:Q503419]]

# %%
print(len(clm_list_values))
print(clm_list_values)
# Out:
# 7
# [[ItemPage('Q1805085'), ItemPage('Q9842'), ItemPage('Q168000')], [ItemPage('Q13371'), ItemPage('Q41506')], [ItemPage('Q1068752'), ItemPage('Q3577853')], [ItemPage('Q41506'), ItemPage('Q7060409')], [ItemPage('Q129421')], [ItemPage('Q168756'), ItemPage('Q992830')], [ItemPage('Q7894738'), ItemPage('Q503419')]]

# %%
print(dir(clm_list_values[0][0]))
print(clm_list_values[0][1].title())
#print(clm_list_values[0][1].getLabel())

repo = site.data_repository()
item = pywikibot.ItemPage(repo, clm_list_values[0][1].title())

item_dict = item.get()
#item_dict
item.labels['en']

#if 'en' in item_dict.labels:
  #  print('The label in English is: ' + item.labels['en'])
    
#clm_dict = item_dict["claims"]
#clm_list = clm_dict["P2069"]

#for clm in clm_list:
   # clm_trgt = clm.getTarget()
   # print(clm_trgt.amount)
   # print(clm_trgt.unit)
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_cache_attrs', '_cmpkey', '_cosmetic_changes_hook', '_defined_by', '_diff_to', '_getInternals', '_get_parsed_page', '_latest_cached_revision', '_link', '_namespace', '_normalizeData', '_normalizeLanguages', '_revisions', '_save', 'addClaim', 'applicable_protections', 'aslink', 'autoFormat', 'backlinks', 'botMayEdit', 'canBeEdited', 'categories', 'change_category', 'clear_cache', 'concept_uri', 'concept_url', 'content_model', 'contributingUsers', 'contributors', 'coordinates', 'data_item', 'data_repository', 'defaultsort', 'delete', 'depth', 'editAliases', 'editDescriptions', 'editEntity', 'editLabels', 'editTime', 
# ...

# %%
#Print the methods available for the object
(print(dir(item)))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__unicode__', '__weakref__', '_cache_attrs', '_cmpkey', '_content', '_cosmetic_changes_hook', '_defined_by', '_diff_to', '_getInternals', '_get_parsed_page', '_isredir', '_latest_cached_revision', '_link', '_namespace', '_normalizeData', '_normalizeLanguages', '_pageid', '_revid', '_revisions', '_save', 'addClaim', 'aliases', 'applicable_protections', 'aslink', 'autoFormat', 'backlinks', 'botMayEdit', 'canBeEdited', 'categories', 'change_category', 'claims', 'clear_cache', 'concept_uri', 'concept_url', 'content_model', 'contributingUsers', 'contributors', 'coordinates', 'data_item', 'data_repository', 'defaultsort', 'delete', 'depth', 'descript
# ...

# %%
#print(item.concept_uri)
#print(item._get_parsed_page)
item_dict = item.get()

# %%
item_dict = item.get()
print(item_dict.keys())
# Out:
# dict_keys(['aliases', 'labels', 'descriptions', 'claims', 'sitelinks'])

# %%
clm_dict = item_dict["claims"] # Get the claim dictionary
print(clm_dict)
# Out:
# {'P373': [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P373', 'datatype': 'string', 'datavalue': {'value': 'Kamala Harris', 'type': 'string'}}, 'type': 'statement', 'id': 'q10853588$132D462F-B996-418E-98C7-0884106DE863', 'rank': 'normal', 'references': [{'snaks': {'P143': [{'snaktype': 'value', 'property': 'P143', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 328}, 'type': 'wikibase-entityid'}}]}, 'snaks-order': ['P143'], 'hash': 'fa278ebfc458360e5aed63d5058cca83c46134f1'}]})], 'P214': [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P214', 'datatype': 'external-id', 'datavalue': {'value': '91053810', 'type': 'string'}}, 'type': 'statement', 'id': 'q10853588$4FFDCD9F-1F33-4771-8EA5-AB38F3344E59', 'rank': 'normal', 'references': [{'snaks': {'P143': [{'snaktype': 'value', 'property': 'P143', 'datatype': 'wikibase-item', 'datavalue': {'value': 
# ...

# %%
clm_list = clm_dict["P1559"]
print(clm_list)
# Out:
# [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P1559', 'datatype': 'monolingualtext', 'datavalue': {'value': {'text': 'Kamala Harris', 'language': 'en'}, 'type': 'monolingualtext'}}, 'type': 'statement', 'id': 'Q10853588$8709c5fc-4c9d-bd93-f79a-2260729becfd', 'rank': 'normal'})]

# %%
for clm in clm_list:
    ...
    clm_trgt = clm.getTarget()
    print(clm_trgt)
    print(type(clm_trgt))
    print(dir(clm_trgt))
# Out:
# {
#     "language": "en",
#     "text": "Kamala Harris"
# }
# <class 'pywikibot.WbMonolingualText'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_items', 'fromWikibase', 'language', 'text', 'toWikibase']

# %%
clm_trgt = clm.getTarget()
print(clm_trgt)
# Out:
# {
#     "language": "en",
#     "text": "Kamala Harris"
# }

# %%
clm_list = clm_dict["P106"]
print(clm_list)
occ_trgt = []
occupation = []

for clm in clm_list:
    ... 
    clm_trgt = clm.getTarget()
    occ_trgt.append(clm_trgt)
    occupation.append(type(clm_trgt))
    print(dir(clm_trgt))
# Out:
# [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P106', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 82955}, 'type': 'wikibase-entityid'}}, 'type': 'statement', 'id': 'Q10853588$4f55b2c2-49fa-0d77-4799-93baa37026a0', 'rank': 'normal'}), Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P106', 'datatype': 'wikibase-item', 'datavalue': {'value': {'entity-type': 'item', 'numeric-id': 40348}, 'type': 'wikibase-entityid'}}, 'type': 'statement', 'id': 'Q10853588$703354FC-95D1-49BB-A8E5-DEC8D020B142', 'rank': 'normal'})]
# ...

# %%
#clm_trgt = clm.getTarget()
#print(clm_trgt)

print(occ_trgt)
print(occupation)
# Out:
# [ItemPage('Q82955'), ItemPage('Q40348')]
# [<class 'pywikibot.page.ItemPage'>, <class 'pywikibot.page.ItemPage'>]

# %%
print(clm_list.getTarget())
#clm_trgt = clm.getTarget()
print(clm_trgt)
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-47-9e5f92ec8d20>", line 1, in <module>
#     print(clm_list.getTarget())
# AttributeError: 'list' object has no attribute 'getTarget'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 1828, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'AttributeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# ...

# %%
for clm in clm_list:
    ...
    clm_trgt = clm.getTarget()
    print(clm_trgt)
    print(type(clm_trgt))
    print(dir(clm_trgt))
# Out:
# a/douglas-adams
# <class 'str'>
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
clm_dict['P2168']
# Out:
# [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P2168', 'datatype': 'external-id', 'datavalue': {'value': '271209', 'type': 'string'}}, 'type': 'statement', 'id': 'Q42$77b4aae6-473c-f860-1918-9ca573cdfb2e', 'rank': 'normal'})]

# %%
clm_list = clm_dict["P2168"]
print(clm_list)
# Out:
# [Claim.fromJSON(DataSite("wikidata", "wikidata"), {'mainsnak': {'snaktype': 'value', 'property': 'P2168', 'datatype': 'external-id', 'datavalue': {'value': '271209', 'type': 'string'}}, 'type': 'statement', 'id': 'Q42$77b4aae6-473c-f860-1918-9ca573cdfb2e', 'rank': 'normal'})]

# %%
for clm in clm_list:
    ...
    clm_trgt = clm.getTarget()
    print(clm_trgt)
    print(type(clm_trgt))
    print(dir(clm_trgt))
# Out:
# 271209
# <class 'str'>
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
item_dict["sitelinks"]
# Out:
# {'afwiki': 'Douglas Adams',
#  'arwiki': 'دوغلاس آدمز',
#  'arzwiki': 'دوجلاس ادامز',
#  'astwiki': 'Douglas Adams',
#  'azbwiki': 'داقلاس آدامز',
#  'azwiki': 'Duqlas Adams',
#  'azwikiquote': 'Duqlas Noel Adams',
#  'barwiki': 'Douglas Adams',
#  'be_x_oldwiki': 'Дуглас Адамз',
#  'bewiki': 'Дуглас Адамс',
#  'bgwiki': 'Дъглас Адамс',
#  'bgwikiquote': 'Дъглас Адамс',
#  'bnwiki': 'ডগলাস অ্যাডামস',
#  'bswiki': 'Douglas Adams',
#  'bswikiquote': 'Douglas Adams',
#  'cawiki': 'Douglas Adams',
#  'cswiki': 'Douglas Adams',
#  'cswikiquote': 'Douglas Adams',
#  'cywiki': 'Douglas Adams',
#  'dawiki': 'Douglas Adams',
#  'dewiki': 'Douglas Adams',
#  'dewikiquote': 'Douglas Adams',
#  'elwiki': 'Ντάγκλας Άνταμς',
#  'elwikiquote': 'Ντάγκλας Άνταμς',
#  'enwiki': 'Douglas Adams',
#  'enwikiquote': 'Douglas Adams',
#  'eowiki': 'Douglas Adams',
#  'eowikiquote': 'Douglas Adams',
#  'eswiki': 'Douglas Adams',
#  'eswikiquote': 'Douglas Adams',
#  'etwiki': 'Douglas Adams',
# ...

# %%
bky_page = pywikibot.Page(site, "Berkeley, California")
bky_page
# Out:
# Page('Berkeley, California')

# %%
# page text with all the wikimarkup and templates 
bky_page_text = bky_page.text

# page text expanded to HTML
bky_page.expand_text()
# Out:
# WARNING: API warning (main): Subscribe to the mediawiki-api-announce mailing list at <https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce> for notice of API deprecations and breaking changes. Use [[Special:ApiFeatureUsage]] to see usage of deprecated features by your application.
# WARNING: API warning (revisions): Because "rvslots" was not specified, a legacy format has been used for the output. This format is deprecated, and in the future the new format will always be used.
# ...

# %%
bky_page_text
# Out:
# '{{Use mdy dates|date=March 2017}}\n{{Infobox settlement\n|name = Berkeley, California\n| official_name       = City of Berkeley\n| settlement_type     = [[City (California)|City]]\n| image_skyline       = Berkeley-downtown-Bay-bridge-SF-in-back-from-Lab.jpg\n| image_caption       = Downtown Berkeley viewed from the Berkeley Hills, with [[San Francisco]] in the background\n| image_flag          = \n| image_seal          = Seal of Berkeley, California.png\n| nickname            = \n| motto               = \n| image_map           = File:Alameda County California Incorporated and Unincorporated areas Berkeley Highlighted 0606000.svg\n| mapsize             = 250px\n| map_caption         = Location of Berkeley in Alameda County, California.\n| pushpin_map             = United States Oakland#United States San Francisco Bay Area#USA California#USA\n| pushpin_label  = Berkeley\n| pushpin_map_caption     = \n| coordinates            = {{coord|37|52|18|N|122|16|22|W|region:US-CA|display=inline
# ...

# %%
# All the geographical coordinates linked in a page (may have multiple per article)
bky_page.coordinates()
# Out:
# [Coordinate(lat=37.87166667, lon=-122.27277778, entity=http://www.wikidata.org/entity/Q2),
#  Coordinate(lat=37.87166667, lon=-122.27472222, entity=http://www.wikidata.org/entity/Q2)]

# %%
#Kamala Harris
kh_page = pywikibot.Page(site, "Kamala Harris")
kh_page.text
# Out:
# WARNING: API warning (main): Subscribe to the mediawiki-api-announce mailing list at <https://lists.wikimedia.org/mailman/listinfo/mediawiki-api-announce> for notice of API deprecations and breaking changes. Use [[Special:ApiFeatureUsage]] to see usage of deprecated features by your application.
# WARNING: API warning (revisions): Because "rvslots" was not specified, a legacy format has been used for the output. This format is deprecated, and in the future the new format will always be used.
# ...

# %% [markdown]
# ## Wikipedia API
# The below block of code uses wikipeidaapi library to extract text from wikipedia pages in text and html formats. It also shows how to extract varoius sections in the wikipage as well as associated URL's listed in the page.
#
# Last block of code shows all the categories, a selected page is associated with.

# %%
#Get single page
wiki_wiki = wikipediaapi.Wikipedia('en')

page_py = wiki_wiki.page('Kamala_Harris')

# %%
#check if page exists
print("Page - Exists: %s" % page_py.exists())
# Out:
# Page - Exists: True

# %%
#Print page summary
print("Page - Title: %s" % page_py.title)
# Out:
# Page - Title: Kamala Harris

# %%
#print page full URL
print(page_py.fullurl)

#print test1 url
#page_py2 = wiki_wiki.page('Test_1')
#print(page_py2.fullurl)
# Out:
# https://en.wikipedia.org/wiki/Kamala_Harris

# %%
#Get full text
wiki_wiki = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI
)

p_wiki = wiki_wiki.page("Test 1")
print(page_py.text)
# Out:
# Kamala Devi Harris (, KAH-mə-lə; born October 20, 1964) is an American attorney and politician who is the junior United States Senator from California, serving since 2017.  A member of the Democratic Party, she previously served as the 32nd Attorney General of California from 2011 to 2017.
# Born in Oakland, California, Harris is a graduate of Howard University and University of California, Hastings.  In the 1990s, Harris worked in the San Francisco District Attorney's Office and City Attorney's Office.  In 2004, Harris was elected District Attorney of San Francisco. Harris was elected California's Attorney General in 2010 and reelected in 2014. On November 8, 2016, she defeated Loretta Sanchez in the 2016 Senate election to succeed outgoing Senator Barbara Boxer, becoming California's third female U.S. Senator and the first of Jamaican or Indian descent.
#
# Early life and education
# ...

# %%
#Get full text html format
wiki_html = wikipediaapi.Wikipedia(
        language='en',
        extract_format=wikipediaapi.ExtractFormat.HTML
)
p_html = wiki_html.page("Kamala_Harris")
print(p_html.text)
# Out:
# <p class="mw-empty-elt">
# </p>
# <p><b>Kamala Devi Harris</b> (<span></span>, <i title="English pronunciation respelling"><span>KAH</span>-mə-lə</i>; born October 20, 1964) is an American attorney and politician who is the junior United States Senator from California, serving since 2017.  A member of the Democratic Party, she previously served as the 32nd Attorney General of California from 2011 to 2017.
# </p><p>Born in Oakland, California, Harris is a graduate of Howard University and University of California, Hastings.  In the 1990s, Harris worked in the San Francisco District Attorney's Office and City Attorney's Office.  In 2004, Harris was elected District Attorney of San Francisco. Harris was elected California's Attorney General in 2010 and reelected in 2014. On November 8, 2016, she defeated Loretta Sanchez in the 2016 Senate election to succeed outgoing Senator Barbara Boxer, becoming California's third female U.S. Senator and the first of Jamaican or Indian descent.</p>
# ...

# %%
#Get page sections
def print_sections(sections, level=0):
        for s in sections:
                print("%s: %s - %s" % ("*" * (level + 1), s.title, s.text[0:40]))
                print_sections(s.sections, level + 1)

print_sections(page_py.sections)
# Out:
# *: Early life and education - Harris was born on October 20, 1964, in
# *: Early career - Harris served as a deputy district attor
# **: District Attorney of the City and County of San Francisco - After the Fajitagate scandal, Harris def
# ***: Violent crimes, felons, incarceration, and conviction rate - While Harris was the San Francisco Distr
# ***: Hate crimes and civil rights - As San Francisco District Attorney, Harr
# *: Attorney General of California -
# **: 2010 election - On November 12, 2008, Harris announced h
# **: 2014 election - Harris announced her intention to run fo
# **: Tenure as California Attorney General -
# ***: Housing - When Harris took office, California was
# ***: Prison conditions and sentencing reform - After the United States Supreme Court in
# ***: Daniel Larsen case - On August 24, 2012, the Los Angeles Time
# ***: Michelle-Lael Norsworthy case - In February 2014, Michelle-Lael Norswort
# ...

# %%
#Get links of this page to other pages
def print_links(page):
        links = page.links
        for title in sorted(links.keys()):
            print("%s: %s" % (title, links[title]))

print_links(page_py)
# Out:
# 115th United States Congress: 115th United States Congress (id: ??, ns: 0)
# 2011 Tucson shooting: 2011 Tucson shooting (id: ??, ns: 0)
# 2012 Democratic National Convention: 2012 Democratic National Convention (id: ??, ns: 0)
# 2017 Las Vegas shooting: 2017 Las Vegas shooting (id: ??, ns: 0)
# Aaron A. Sargent: Aaron A. Sargent (id: ??, ns: 0)
# Abram Williams: Abram Williams (id: ??, ns: 0)
# Actually innocent: Actually innocent (id: ??, ns: 0)
# Adam Schiff: Adam Schiff (id: ??, ns: 0)
# Affordable Care Act: Affordable Care Act (id: ??, ns: 0)
# Alameda County, California: Alameda County, California (id: ??, ns: 0)
# Alan Cranston: Alan Cranston (id: ??, ns: 0)
# Alan Lowenthal: Alan Lowenthal (id: ??, ns: 0)
# Alex Kozinski: Alex Kozinski (id: ??, ns: 0)
# Alex Padilla: Alex Padilla (id: ??, ns: 0)
# Ally Financial: Ally Financial (id: ??, ns: 0)
# Alpha Kappa Alpha: Alpha Kappa Alpha (id: ??, ns: 0)
# Ami Bera: Ami Bera (id: ??, ns: 0)
# ...

# %%
#Get page categories
def print_categories(page):
        categories = page.categories
        for title in sorted(categories.keys()):
            print("%s: %s" % (title, categories[title]))


print("Categories")
print_categories(page_py)
# Out:
# Categories
# Category:1964 births: Category:1964 births (id: ??, ns: 14)
# Category:20th-century American politicians: Category:20th-century American politicians (id: ??, ns: 14)
# Category:20th-century American women: Category:20th-century American women (id: ??, ns: 14)
# Category:20th-century American women writers: Category:20th-century American women writers (id: ??, ns: 14)
# Category:20th-century American writers: Category:20th-century American writers (id: ??, ns: 14)
# Category:20th-century women politicians: Category:20th-century women politicians (id: ??, ns: 14)
# Category:21st-century American politicians: Category:21st-century American politicians (id: ??, ns: 14)
# Category:21st-century American women: Category:21st-century American women (id: ??, ns: 14)
# Category:21st-century American women writers: Category:21st-century American women writers (id: ??, ns: 14)
# Category:21st-century American writers: Category:21st-century American writers (id: ??, ns: 14)
# ...

# %%
#Get all pages from a particular category
def print_categorymembers(categorymembers, level=0, max_level=2):
        for c in categorymembers.values():
            print("%s: %s (ns: %d)" % ("*" * (level + 1), c.title, c.ns))
            if c.ns == wikipediaapi.Namespace.CATEGORY and level <= max_level:
                print_categorymembers(c.categorymembers, level + 1)


cat = wiki_wiki.page("Category:American politicians of Indian descent")
print("Category members: Category:American politicians of Indian descent")
print_categorymembers(cat.categorymembers)
# Out:
# Category members: Category:American politicians of Indian descent
# *: Kiran Ahuja (ns: 0)
# *: Vishal Amin (ns: 0)
# *: Preeta D. Bansal (ns: 0)
# *: Sandy Baruah (ns: 0)
# *: Nandita Berry (ns: 0)
# *: Nisha Desai Biswal (ns: 0)
# *: Neil Chatterjee (ns: 0)
# *: Jay Chaudhuri (ns: 0)
# *: Joy Cherian (ns: 0)
# *: Swati Dandekar (ns: 0)
# *: Harmeet Dhillon (ns: 0)
# *: Manka Dhingra (ns: 0)
# *: Shefali Razdan Duggal (ns: 0)
# *: Vijaya Lakshmi Emani (ns: 0)
# *: Manju Ganeriwala (ns: 0)
# *: Gurbir Grewal (ns: 0)
# *: Vanita Gupta (ns: 0)
# *: Nikki Haley (ns: 0)
# *: Kamala Harris (ns: 0)
# *: Hiral Tipirneni (ns: 0)
# *: Pramila Jayapal (ns: 0)
# *: Ash Kalra (ns: 0)
# *: Nimi McConigley (ns: 0)
# *: Aruna Miller (ns: 0)
# *: Farah Pandith (ns: 0)
# *: Prachi Patankar (ns: 0)
# *: Rachel Paulose (ns: 0)
# *: Jenifer Rajkumar (ns: 0)
# *: Kesha Ram (ns: 0)
# *: Neomi Rao (ns: 0)
# *: Vineeta Rastogi (ns: 0)
# *: Harpreet Sandhu (politician) (ns: 0)
# *: Reshma Saujani (ns: 0)
# ...

# %% [markdown]
# ## Wikipedia and nltk library
# The below blocks of code shows the usage of wikipedia and nltk(NLP) librarires to extract information from wikipages and count+show most frequently used words in the page.

# %%
#nltk is a good library for natural language processing
import nltk
import wikipedia

# %%
#In this example, we will get the page for Berkeley, California and count the most commonly used words in the article.
bky = wikipedia.page("Berkeley, California")
bky
# Out:
# <WikipediaPage 'Berkeley, California'>

# %%
bk_split = bky.content.split()

# %%
bk_split[:10]
# Out:
# ['Berkeley', '(', 'BURK-lee)', 'is', 'a', 'city', 'on', 'the', 'east', 'shore']

# %%
fdist1 = nltk.FreqDist(bk_split)
fdist1.most_common(20)
# Out:
# [('the', 685),
#  ('of', 451),
#  ('and', 304),
#  ('in', 244),
#  ('Berkeley', 206),
#  ('to', 178),
#  ('a', 169),
#  ('The', 110),
#  ('is', 77),
#  ('for', 76),
#  ('was', 73),
#  ('by', 71),
#  ('with', 60),
#  ('as', 53),
#  ('===', 50),
#  ('from', 49),
#  ('on', 47),
#  ('has', 46),
#  ('at', 42),
#  ('were', 42)]

# %%
print(bky.references[:10])
print(bky.links[:10])
# Out:
# ['http://doi.org/10.1016/0962-6298(92)90046-V', 'http://doi.org/10.1037/h0098852', 'http://doi.org/10.1097/00001888-200105000-00058', 'http://doi.org/10.1111/1467-8330.00048', 'http://doi.org/10.2747/0272-3638.30.6.611', 'http://tools.wmflabs.org/geohack/geohack.php?pagename=Berkeley,_California&params=37_52_18_N_122_16_29_W_type:city', 'http://tools.wmflabs.org/geohack/geohack.php?pagename=Berkeley,_California&params=37_52_18_N_122_16_22_W_region:US-CA_type:city(112580)', 'http://www.jstor.org/stable/29768172', 'http://www.ncbi.nlm.nih.gov/pmc/articles/PMC4098056', 'http://www.ncbi.nlm.nih.gov/pubmed/24826829']
# ['1868 Hayward earthquake', '1890 United States Census', '1900 United States Census', '1906 San Francisco earthquake', '1910 United States Census', '1920 United States Census', '1923 Berkeley, California fire', '1923 Berkeley Fire', '1923 Berkeley fire', '1930 United States Census']
